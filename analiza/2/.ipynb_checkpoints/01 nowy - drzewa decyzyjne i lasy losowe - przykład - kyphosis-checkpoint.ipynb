# %% [markdown]
# # Drzewa decyzyjne i lasy losowe

# %% [markdown]
# **Drzewa decyzyjne** (ang. decision trees), zwane równiez drzewami klasyfikacyjnymi (ang. classification trees), opierają się o drzewiastą strukturę.
#
# **Lasy losowe** (random forests) będące uogólnieniem idei drzew decyzyjnych zalicza się do procedur agregujących (ensemble method). Działanie lasów losowych polega na klasyfikacji za pomocą grupy drzew decyzyjnych. Koncowa decyzja jest podejmowana w wyniku głosowania większościowego nad klasami wskazanymi przez poszczególne drzewa decyzyjne.
#
# <img src=".\images\drzewo.jpg" width="220" height="220">
#
#
# ## Dane
#
# Dane zebrano na 83 pacjentach (dzieciach) poddanych korekcji chirurgii kręgosłupa. Celem było określenie ważnych czynników ryzyka na kifozę po operacji. Czynnikami ryzyka są wiek w miesiącach, pierwszy z kręgów i liczby zaangażowanych poziomów.
# Przypadki 15 i 28 zostały usunięta, w związku z tym zostaje 81 przypadków.
#
# Kolumny:
# * Age = miesiące
# * Start = numer pierwszego (najwyżej) operowanego kręgu.
# * Number = liczba zaangażowanych kręgów
# * Kyphosis = kifoza, present jeśli jest obecna, absent jeśli nieobecna
#
# Kifoza pogłębiona (inaczej plecy okrągłe) to choroba kręgosłupa, której cechą charakterystyczną jest nadmierne wygięcie kręgosłupa ku tyłowi w odcinku piersiowym i krzyżowym.
#
# <img src=".\images\kifoza.png" width="220" height="220">
#
# http://www.poradnikzdrowie.pl/zdrowie/kregoslup/kifoza-okragle-plecy-hiperkifoza-przyczyny-objawy-leczenie-i-cwiczenia_33614.html
#
# Link: https://www.kaggle.com/abbasit/kyphosis-dataset
#
# Źródło: John M. Chambers and Trevor J. Hastie eds. (1992) Statistical Models in S, Wadsworth and Brooks/Cole, Pacific Grove, CA.

# %% [markdown]
# ## Import bibliotek

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Pobranie danych

# %%
df = pd.read_csv('.\\Data\\kyphosis.csv')

# %%
df.head(2)
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14

# %%
df.tail()
# Out:
#    Kyphosis  Age  Number  Start
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
df.describe()
# Out:
#               Age     Number      Start
# count   81.000000  81.000000  81.000000
# mean    83.654321   4.049383  11.493827
# std     58.104251   1.619423   4.883962
# min      1.000000   2.000000   1.000000
# 25%     26.000000   3.000000   9.000000
# 50%     87.000000   4.000000  13.000000
# 75%    130.000000   5.000000  16.000000
# max    206.000000  10.000000  18.000000

# %% [markdown]
# ## EDA - eksploracyjna analiza danych

# %%
plt.rcParams["figure.figsize"] = (5, 4); #ustawienie rozmiarów wykresów

# %% [markdown]
# Przyjrzyjmy się targetowi:

# %%
sns.countplot(data = df, x ='Kyphosis', label='liczba');

# %% [markdown]
# Wykonajmy wykresy rozproszenia dla kombinacji par zmiennych.

# %%
sns.pairplot(df,hue='Kyphosis',palette='Set1', height=2); #height=2 w calach

# %% [markdown]
# Sprawdźmy te korelacje:

# %%
sns.heatmap(df[['Age','Start','Number']].corr(), annot = True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Zestaw treningowy i zestaw testowy
#
# Podzielmy dane na zestaw treningowy i zestaw testowy!

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis',axis=1)
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.30)

# %%
X_test.describe()
# Out:
#               Age     Number      Start
# count   25.000000  25.000000  25.000000
# mean    80.400000   4.000000  10.880000
# std     61.465437   1.554563   5.150405
# min      1.000000   2.000000   1.000000
# 25%     31.000000   3.000000   8.000000
# 50%     73.000000   4.000000  12.000000
# 75%    121.000000   5.000000  15.000000
# max    206.000000   9.000000  17.000000

# %%
X_train.describe()
# Out:
#               Age     Number      Start
# count   56.000000  56.000000  56.000000
# mean    85.107143   4.071429  11.767857
# std     57.053939   1.660856   4.782510
# min      1.000000   2.000000   1.000000
# 25%     25.000000   3.000000   9.000000
# 50%     89.000000   4.000000  13.000000
# 75%    132.250000   5.000000  16.000000
# max    178.000000  10.000000  18.000000

# %% [markdown]
# ## Drzewa decyzyjne
#
# Zaczniemy od treningu pojedynczego drzewa decyzyjnego.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predykcja

# %%
# bez index'u będzie błąd "If using all scalar values, you must pass an index"
data = pd.DataFrame(data={'Age': 34, 'Number': 4, 'Start':3},index=[0]) 
data
# Out:
#    Age  Number  Start
# 0   34       4      3

# %%
# lub
data = pd.DataFrame(data={'Age':[34], 'Number': [4], 'Start':[3]})
data
# Out:
#    Age  Number  Start
# 0   34       4      3

# %%
predictions = dtree.predict(data)
print('Kyphosis = ' + predictions[0])
# Out:
# Kyphosis = absent

# %% [markdown]
# ## Prognozowanie i ocena
#
# Przeanalizujmy nasze drzewo decyzyjne.

# %%
 dtree_pred = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test, dtree_pred))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.76      0.89      0.82        18
#      present       0.50      0.29      0.36         7
#
#     accuracy                           0.72        25
#    macro avg       0.63      0.59      0.59        25
# weighted avg       0.69      0.72      0.69        25

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,  dtree_pred)
# Out:
# 0.72

# %%
print(confusion_matrix(y_test, dtree_pred))
# Out:
# [[16  2]
#  [ 5  2]]

# %%
cm = confusion_matrix(y_test, dtree_pred)
sns.heatmap(cm, annot=True)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
feature_importances = pd.DataFrame(dtree.feature_importances_,
                                   index = X_train.columns,
                                   columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#         importance
# Start     0.459751
# Age       0.270224
# Number    0.270025

# %% [markdown]
# ## Wizualizacja drzewa (wersja 1)

# %%
from IPython.display import Image  
# from sklearn.externals.six import StringIO  

from io import StringIO

from sklearn.tree import export_graphviz
import pydot 

# uruchomić konsolę jako administrator // lepiej wykorzystać pip
# conda install -c anaconda pydot
# conda install graphviz

# %%
# https://graphviz.readthedocs.io/en/stable/manual.html
    
# dowload and install: graphviz-2.38.msi
# https://graphviz.gitlab.io/_pages/Download/Download_windows.html
# https://graphviz.org/download/

import os
# os.environ["PATH"] += os.pathsep + 'C:/anaconda3/Lib/site-packages/graphviz-2.38/bin'
# os.environ["PATH"] += os.pathsep + 'C:\\ProgramData\\Anaconda3\\pkgs\\graphviz-2.38-hfd603c8_2\\Library\\bin'
# nie trzeba dorzucać wtedy do zmiennych środowiskowych PATH

#os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'

#Jak nie działa, tp czasem lepiej:
#conda remove graphviz

# Najważniejsze:
# conda install graphviz
#conda install python-graphviz

# %%
# lub bezpośrednio
! pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\ksmol\anaconda3\lib\site-packages (0.20.1)

# %% [markdown]
# Kilka przykładów z graphviz

# %%
from graphviz import Digraph

g = Digraph('G', filename='hello.gv')

g.edge('Hello', 'World')

# w notatniku
g

# %%
# w pliku
g.view()
# Out:
# 'hello.gv.pdf'

# %%
dot = Digraph(comment='The Round Table')

dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

dot

# %% [markdown]
# **Wracamy do przykładu:**

# %%
features = list(df.columns[1:])
features
# Out:
# ['Age', 'Number', 'Start']

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())

# %% [markdown]
# Do pomiaru jednorodności liczby obserwacji wpadających do poszczególnych klas w podgrupach domyślnie jest stosowany wskaźnik Giniego.
# Z rysunku możemy odczytać m.in. kryteria podziału zmiennych, liczby obserwacji z każdej klasy reprezentowanej przez poszczególne węzły (value).
# Dla naszego przykładu: 'Age':12,'Start':3,'Number':12 wychodzi 1 próbka typu absent. Prawdopodobieństwo wyniku liczymy ilość w danej klasie (odpowiednia pozycja z value) podzielona na ilość wszystkich próbek (samples).

# %% [markdown]
# ## Wizualizacja drzewa (wersja 2)

# %%
import pydotplus

# %%
df["Kyphosis"] = df["Kyphosis"].astype("category")
class_names = df.Kyphosis.cat.categories
feature_names = list(df.columns[1:])

# %%
# export graph
dot_data = StringIO()
export_graphviz(dtree,
                out_file=dot_data,
                feature_names=feature_names,
                class_names=class_names,
                special_characters=True,
                rounded=True,
                filled=True)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('graph.png')
Image(graph.create_png())

# %% [markdown]
# ## Losowe lasy
#
# Teraz porównajmy model drzewa decyzyjnego z losowym lasem.

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train);

# %%
rfc_pred = rfc.predict(X_test)

# %%
accuracy_score(y_test, rfc_pred)
# Out:
# 0.76

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[17  1]
#  [ 5  2]]

# %%
cm = confusion_matrix(y_test, rfc_pred)
sns.heatmap(cm, annot=True)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.77      0.94      0.85        18
#      present       0.67      0.29      0.40         7
#
#     accuracy                           0.76        25
#    macro avg       0.72      0.62      0.62        25
# weighted avg       0.74      0.76      0.72        25

# %%
print('Kyphosis = ' + rfc.predict(data)[0])
# Out:
# Kyphosis = absent

# %% [markdown]
# # Bibliografia

# %% [markdown]
# Przykład na podstawie [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) - Jake VanderPlas; Książkę można znaleźć na [GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).

# %% [markdown]
# # Zadania

# %% [markdown]
# 1. Wyznacz współczynniki TP, TN, FP, FN i na ich podstawie wyznacz dokładność (accurancy i precision).
# 1. Załaduj plik "Dataset - Bikes.xlsx" i stwórz dla tych danych model Decision Tree lub Random Forest
# 1. Dla danych Kyphosis określ dokładność w zależności od ilości drzew w algorytmie Random Forest (narysuj wykres)

# %% [markdown]
# ## Zadanie 1

# %% [markdown]
# Wyznacz współczynniki TP, TN, FP, FN i na ich podstawie wyznacz dokładność (accurancy i precision).

# %%
print(classification_report(y_test, dtree_pred))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.76      0.89      0.82        18
#      present       0.50      0.29      0.36         7
#
#     accuracy                           0.72        25
#    macro avg       0.63      0.59      0.59        25
# weighted avg       0.69      0.72      0.69        25

# %%
# Positive = present
TN, FP, FN, TP = confusion_matrix(y_test, dtree_pred).ravel()

# %%
print("Dokładność (accurancy) drzew decyzyjnych:")
(TP+TN)/(TP+TN+FP+FN)
# Out:
# Dokładność (accurancy) drzew decyzyjnych:
# 0.72

# %%
print("Precyzja drzew decyzyjnych (present):")
(TP)/(TP+FP)
# Out:
# Precyzja drzew decyzyjnych (present):
# 0.5

# %%
print("Precyzja drzew decyzyjnych (absent):")
(TN)/(TN+FN)
# Out:
# Precyzja drzew decyzyjnych (absent):
# 0.7619047619047619

# %% [markdown]
# ## Zadanie 2

# %% [markdown]
# Załaduj plik "Dataset - Bikes.xlsx" i stwórz dla tych danych model Decision Tree lub Random Forest.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix

# %%
df = pd.read_excel('.\\Data\\Dataset - Bikes.xlsx',sheet_name='Table Analysis Tools Sample')

# %%
#przemieszanie
df = df.sample(frac = 1, random_state=12347)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 767 to 952
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    1000 non-null   object
#  2   Gender            1000 non-null   object
#  3   Income            1000 non-null   int64
#  4   Children          1000 non-null   int64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        1000 non-null   object
#  8   Cars              1000 non-null   int64
#  9   Commute Distance  1000 non-null   object
#  10  Region            998 non-null    object
#  11  Age               997 non-null    float64
#  12  Purchased Bike    1000 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 109.4+ KB

# %%
df.columns
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %%
df = df.drop('ID',axis=1)

# %%
df.columns
# Out:
# Index(['Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %% [markdown]
# Niestety Lasy losowe nie akceptują wartości NaN.

# %%
df.isnull().sum()
# Out:
# Marital Status      0
# Gender              0
# Income              0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              2
# Age                 3
# Purchased Bike      0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy="most_frequent")
Region = imputer.fit_transform(df['Region'].to_numpy().reshape(-1,1)) #musi mieć odpowiedni wymiar [[]], zamiast []

imputer = SimpleImputer(missing_values=np.nan, strategy="mean")
Age = imputer.fit_transform(df['Age'].to_numpy().reshape(-1,1))

# %%
df.Region = Region[:,0]
df.Age = Age[:,0]

# %%
df.isnull().sum()
# Out:
# Marital Status      0
# Gender              0
# Income              0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Purchased Bike      0
# dtype: int64

# %% [markdown]
# Część klasyfikatów nie akceptuje wartości, które nie są numeryczne.

# %%
df.columns
# Out:
# Index(['Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 767 to 952
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Marital Status    1000 non-null   object
#  1   Gender            1000 non-null   object
#  2   Income            1000 non-null   int64
#  3   Children          1000 non-null   int64
#  4   Education         1000 non-null   object
#  5   Occupation        1000 non-null   object
#  6   Home Owner        1000 non-null   object
#  7   Cars              1000 non-null   int64
#  8   Commute Distance  1000 non-null   object
#  9   Region            1000 non-null   object
#  10  Age               1000 non-null   float64
#  11  Purchased Bike    1000 non-null   object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 101.6+ KB

# %%
X = df.drop('Purchased Bike',axis=1)
# zamiana wartości typu object (kategorii) na 0 i 1, będą dodatkowe kolumny,
X = pd.get_dummies(X)
y = df['Purchased Bike']

# %%
X.columns
# Out:
# Index(['Income', 'Children', 'Cars', 'Age', 'Marital Status_Married',
#        'Marital Status_Single', 'Gender_Female', 'Gender_Male',
#        'Education_Bachelors', 'Education_Graduate Degree',
#        'Education_High School', 'Education_Partial College',
#        'Education_Partial High School', 'Occupation_Clerical',
#        'Occupation_Management', 'Occupation_Manual', 'Occupation_Professional',
#        'Occupation_Skilled Manual', 'Home Owner_No', 'Home Owner_Yes',
#        'Commute Distance_0-1 Miles', 'Commute Distance_1-2 Miles',
#        'Commute Distance_10+ Miles', 'Commute Distance_2-5 Miles',
#        'Commute Distance_5-10 Miles', 'Region_Europe', 'Region_North America',
#        'Region_Pacific'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.30)

# %% [markdown]
# ### Drzewo decyzyjne

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
dtree_pred = dtree.predict(X_test)

print(classification_report(y_test, dtree_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.66      0.67      0.66       157
#          Yes       0.63      0.62      0.62       143
#
#     accuracy                           0.64       300
#    macro avg       0.64      0.64      0.64       300
# weighted avg       0.64      0.64      0.64       300

# %% [markdown]
# ### Lasy losowe

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train,y_train)
rfc_pred = rfc.predict(X_test)

print(classification_report(y_test, rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.72      0.74      0.73       157
#          Yes       0.70      0.68      0.69       143
#
#     accuracy                           0.71       300
#    macro avg       0.71      0.71      0.71       300
# weighted avg       0.71      0.71      0.71       300

# %% [markdown]
# ## Zadanie 3

# %% [markdown]
# Dla danych Kyphosis określ dokładność w zależności od ilości drzew w algorytmie Random Forest (narysuj wykres)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
df = pd.read_csv('.\\Data\\kyphosis.csv')

X = df.drop('Kyphosis',axis=1)
y = df['Kyphosis']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.30)

# %%
df_metrics=pd.DataFrame(columns=['n_tree','precission','recall','f1-score','accurancy'])
for n_estimators in range(5,201,5):
    rfc = RandomForestClassifier(n_estimators=n_estimators)
    rfc.fit(X_train, y_train);
    y_pred = rfc.predict(X_test)
    p, r, f, s = metrics.precision_recall_fscore_support(y_test, y_pred, average='weighted')
    a = accuracy_score(y_test, y_pred)
    new_row = {'n_tree':n_estimators,'precission':p,'recall':r,'f1-score':f,'accurancy':a}
    df_metrics.loc[len(df_metrics)] = new_row

# %%
df_metrics.head()
# Out:
#    n_tree  precission  recall  f1-score  accurancy
# 0       5    0.672174    0.72  0.659295       0.72
# 1      10    0.843478    0.80  0.756640       0.80
# 2      15    0.743030    0.76  0.724000       0.76
# 3      20    0.672174    0.72  0.659295       0.72
# 4      25    0.510000    0.68  0.582857       0.68

# %%
df_metrics.plot(x='n_tree', y=['precission','recall','f1-score','accurancy'], kind='line')
# Out:
# <AxesSubplot: xlabel='n_tree'>

# %% [markdown]
# # Dodatek (Automatyczne wyszukiwanie parametrów)

# %% [markdown]
# https://scikit-learn.org/stable/getting_started.html
#
# https://scikit-learn.org/stable/modules/grid_search.html#grid-search
#
# https://scikit-learn.org/stable/modules/model_evaluation.html

# %% [markdown]
# Wszystkie estymatory posiadają parametry (często nazywane **hiperparametrami** w literaturze), które można dostosować.
#
# Ogólna siła uogólniania estymatora często zależy krytycznie od kilku parametrów. Na przykład **RandomForestClassifier** posiada parametr **n_estimators**, który określa liczbę drzew w lesie, oraz parametr **max_depth**, który określa maksymalną głębokość każdego drzewa. Często nie jest jasne, jakie dokładnie powinny być wartości tych parametrów, ponieważ zależą one od dostępnych danych.
#
# **Scikit-learn** dostarcza narzędzi do automatycznego znalezienia najlepszych kombinacji parametrów (poprzez walidację krzyżową). W poniższym przykładzie przeszukujemy losowo przestrzeń parametrów lasu losowego za pomocą obiektu **RandomizedSearchCV**. Po zakończeniu przeszukiwania, **RandomizedSearchCV** zachowuje się jak **RandomForestClassifier**, który został dopasowany do najlepszego zestawu parametrów.

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from scipy.stats import randint

X = df.drop('Kyphosis',axis=1)
y = df['Kyphosis']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size = 0.3)

# Zdefiniuj przestrzeń parametrów, która będzie poddana przeszukiwaniu.
param_distributions = {'n_estimators': randint(10, 200),
                       'max_depth':    randint(5, 10)}

# Teraz stwórz obiekt SearchCV i dopasuj go do danych.
search = RandomizedSearchCV(estimator=RandomForestClassifier(random_state=0),
                            n_iter=25,
                            param_distributions=param_distributions,
                            random_state=0,
                            scoring = 'accuracy')
search.fit(X_train, y_train)
search.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 98}

# %%
search.score(X_test, y_test)
# Out:
# 0.68

# %% [markdown]
# Przykład z dataset 'iris' i zmianą parametrów modelu (GridSearchCV):

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
iris = datasets.load_iris()
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
svc = svm.SVC()
clf = GridSearchCV(svc, parameters)
clf.fit(iris.data, iris.target)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10], 'kernel': ('linear', 'rbf')})

# %%
clf.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
sorted(clf.cv_results_.keys())
# Out:
# ['mean_fit_time',
#  'mean_score_time',
#  'mean_test_score',
#  'param_C',
#  'param_kernel',
#  'params',
#  'rank_test_score',
#  'split0_test_score',
#  'split1_test_score',
#  'split2_test_score',
#  'split3_test_score',
#  'split4_test_score',
#  'std_fit_time',
#  'std_score_time',
#  'std_test_score']

# %%
clf.best_score_
# Out:
# 0.9800000000000001

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %% [markdown]
# # Dodatek (granice decyzyjne)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from IPython.display import Image
from sklearn.tree import DecisionTreeClassifier
sns.set()

# %%
iris = load_iris()
data = iris.data
targets = iris.target
feature_names = [name.replace(' ', '_')[:-5] for name in iris.feature_names]
class_names = iris.target_names

print('Liczba próbek:', len(data))
print('Kształt danych', data.shape)
print('Nazwy zmiennych objaśniających:', feature_names)
print('Nazwy kategorii kosaćca:', class_names)
# Out:
# Liczba próbek: 150
# Kształt danych (150, 4)
# Nazwy zmiennych objaśniających: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
# Nazwy kategorii kosaćca: ['setosa' 'versicolor' 'virginica']

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# |details-start|
# **References**
# |details-split|
#
# - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#   Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#   Mathematical Statistics" (John Wiley, NY, 1950).
# - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#   (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
# - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#   Structure and Classification Rule for Recognition in Partially Exposed
#   Environments".  IEEE Transactions on Pattern Analysis and Machine
#   Intelligence, Vol. PAMI-2, No. 1, 67-71.
# - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#   on Information Theory, May 1972, 431-433.
# - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#   conceptual clustering system finds 3 classes in the data.
# - Many, many more ...
#
# |details-end|

# %%
data_targets = np.c_[data, targets]
df = pd.DataFrame(data_targets, columns=feature_names + ['class'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  class
# 0           5.1          3.5           1.4          0.2    0.0
# 1           4.9          3.0           1.4          0.2    0.0
# 2           4.7          3.2           1.3          0.2    0.0
# 3           4.6          3.1           1.5          0.2    0.0
# 4           5.0          3.6           1.4          0.2    0.0

# %%
df.describe().apply(lambda x: round(x, 2))
# Out:
#        sepal_length  sepal_width  petal_length  petal_width   class
# count        150.00       150.00        150.00       150.00  150.00
# mean           5.84         3.06          3.76         1.20    1.00
# std            0.83         0.44          1.77         0.76    0.82
# min            4.30         2.00          1.00         0.10    0.00
# 25%            5.10         2.80          1.60         0.30    0.00
# 50%            5.80         3.00          4.35         1.30    1.00
# 75%            6.40         3.30          5.10         1.80    2.00
# max            7.90         4.40          6.90         2.50    2.00

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sepal_length', y='sepal_width', hue='class', data=df, legend='full')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x = 'petal_length', y = 'petal_width', hue='class', data=df, legend='full')
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='petal_width'>

# %%
from sklearn.tree import export_graphviz
from mlxtend.plotting import plot_decision_regions
from six import StringIO
from IPython.display import Image
import pydotplus

# %%
def make_decision_tree(max_depth=1):
    # train model
    tree_clf = DecisionTreeClassifier(max_depth=max_depth, random_state=30)
    tree_clf.fit(X, y)

    # export graph
    dot_data = StringIO()
    export_graphviz(tree_clf,
                   out_file=dot_data,
                   feature_names=feature_names[2:],
                   class_names=class_names,
                   special_characters=True,
                   rounded=True,
                   filled=True)
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    graph.write_png('graph.png')
    
    
    # plot decision boundries
    colors='#f1865b,#31c30f,#64647F,#d62728,#9467bd,#8c564b,#e377c2,#7f7f7f,#bcbd22,#17becf'
    plt.figure(figsize=(8, 6))
    ax = plot_decision_regions(X, y, tree_clf, legend=0, colors=colors)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, ['setosa', 'versicolor', 'virginica'], framealpha=0.3)
    plt.xlabel('petal length (cm)')
    plt.ylabel('petal width (cm)')
    plt.title('Drzewo decyzyjne: max_depth={}'.format(max_depth))
    
    # accuracy
    print('Dokładność modelu: ' + str(round(tree_clf.score(X, y) * 100, 2)) + '%')
    return Image(graph.create_png())

# %% [markdown]
# ## Przygotowanie danych do modelu

# %%
X = df.copy()
X = X[['petal_length', 'petal_width', 'class']]
y = X.pop('class')

# %%
# Konwersja DataFrame do tablic numpy
X = X.values
y = y.values.astype('int16')

# %% [markdown]
# ## Tworzenie modeli

# %%
make_decision_tree()
# Out:
# Dokładność modelu: 66.67%

# %%
make_decision_tree(2)
# Out:
# Dokładność modelu: 96.0%

# %%
make_decision_tree(3)
# Out:
# Dokładność modelu: 97.33%

# %%
make_decision_tree(4)
# Out:
# Dokładność modelu: 98.67%

# %%
make_decision_tree(5)
# Out:
# Dokładność modelu: 99.33%

# %% [markdown]
# ## Granice inaczej

# %%
from mlxtend.plotting import plot_decision_regions

# %%
tree_clf = DecisionTreeClassifier(max_depth=4, random_state=30)
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=30)

# %%
plot_decision_regions(X_train.to_numpy(), y_train.to_numpy().astype(np.int_), tree_clf)
plt.xlabel(feature_names[2])
plt.ylabel(feature_names[3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25040\3598187818.py in <module>
# ----> 1 plot_decision_regions(X_train.to_numpy(), y_train.to_numpy().astype(np.int_), tree_clf)
#       2 plt.xlabel(feature_names[2])
#       3 plt.ylabel(feature_names[3])
#
# ValueError: invalid literal for int() with base 10: 'absent'
